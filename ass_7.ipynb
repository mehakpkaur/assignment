# %%
#Q1
import numpy as np
import pandas as pd
#Part I
#1
np.random.seed(102317094)
#2
sales_data = np.random.randint(1000, 5000, size=(12, 4))
months=["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
categories=["Electronics", "Clothing", "Home & Kitchen", "Sports"]
#3
df = pd.DataFrame(sales_data, columns=categories, index=months)
df.head()
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         4682      1247            3784    3493
# Feb         1627      2212            4189    3891
# Mar         3068      3679            1592    3290
# Apr         4481      3611            1187    2209
# May         2192      4176            1362    3779

# %%
#Part II
#1
print(df.head())
print(df.describe())
#2
total_sales_category = df.sum()
total_sales_month = df.sum(axis=1)
print("\nTotal Sales Per Category:\n", total_sales_category)
print("\nTotal Sales Per Month:\n", total_sales_month)
#3
df_growth = df.pct_change() * 100
df_growth = df_growth.round(2)
print("\nAverage Sales Growth (%):\n", df_growth)
#4
df["Total Sales"] = df.sum(axis=1)
df["Growth Rate"] = df["Total Sales"].pct_change() * 100
df["Growth Rate"] = df["Growth Rate"].round(2)
print("\nUpdated DataFrame:\n", df)
#5
df["Clothing"] = df["Clothing"] * 0.85
print("\nDataFrame after Discount:\n", df)
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan         4682   1059.95            3784    3493        13206          NaN
# Feb         1627   1880.20            4189    3891        11919        -9.75
# Mar         3068   3127.15            1592    3290        11629        -2.43
# Apr         4481   3069.35            1187    2209        11488        -1.21
# May         2192   3549.60            1362    3779        11509         0.18
#        Electronics     Clothing  Home & Kitchen       Sports   Total Sales  \
# count    12.000000    12.000000       12.000000    12.000000     12.000000
# mean   3323.083333  2442.970833     2627.666667  3236.000000  12060.833333
# std    1013.612662  1048.254910     1238.796801   962.369519   1457.902780
# min    1627.000000  1043.800000     1138.000000  1451.000000   9484.000000
# 25%    2648.750000  1380.612500     1534.500000  2665.000000  11503.750000
# 50%    3323.000000  2847.500000     2517.500000  3425.000000  11805.000000
# 75%    4179.500000  3227.662500     3739.750000  3807.000000  13005.000000
# max    4682.000000  3764.650000     4325.000000  4746.000000  15081.000000
#
#        Growth Rate
# count    11.000000
# mean      0.908182
# std      20.578490
# min     -37.110000
# 25%      -8.800000
# 50%      -1.210000
# 75%      14.355000
# max      36.420000
#
# Total Sales Per Category:
#  Electronics        39877.00
# Clothing           29315.65
# Home & Kitchen     31532.00
# Sports             38832.00
# Total Sales       144730.00
# Growth Rate            9.99
# dtype: float64
#
# Total Sales Per Month:
#  Jan    26224.95
# Feb    23496.45
# Mar    22703.72
# Apr    22433.14
# May    22391.78
# Jun    26355.03
# Jul    23874.65
# Aug    29521.05
# Sep    18723.14
# Oct    25449.07
# Nov    20328.03
# Dec    22795.63
# dtype: float64
#
# Average Sales Growth (%):
#       Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan          NaN       NaN             NaN     NaN          NaN          NaN
# Feb       -65.25     77.39           10.70   11.39        -9.75          NaN
# Mar        88.57     66.32          -62.00  -15.45        -2.43       -75.08
# Apr        46.06     -1.85          -25.44  -32.86        -1.21       -50.21
# May       -51.08     15.65           14.74   71.07         0.18      -114.88
# Jun        63.23    -70.59          217.55    9.31        15.23      8361.11
# Jul       -21.72    203.75          -33.57  -31.81        -7.85      -151.54
# Aug       -22.13     18.74           29.66   68.48        23.40      -398.09
# Sep       105.96    -68.73          -55.54  -58.89       -37.11      -258.59
# Oct       -34.26    123.03          113.71   72.07        36.42      -198.14
# Nov        26.75    -44.84          -67.84   10.72       -20.37      -155.93
# Dec         8.98    134.68           89.98  -60.96        13.48      -166.18
#
# Updated DataFrame:
#       Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan         4682   1059.95            3784    3493     26224.95          NaN
# Feb         1627   1880.20            4189    3891     23496.45       -10.40
# Mar         3068   3127.15            1592    3290     22703.72        -3.37
# Apr         4481   3069.35            1187    2209     22433.14        -1.19
# May         2192   3549.60            1362    3779     22391.78        -0.18
# Jun         3578   1043.80            4325    4131     26355.03        17.70
# Jul         2801   3170.50            2873    2817     23874.65        -9.41
# Aug         2181   3764.65            3725    4746     29521.05        23.65
# Sep         4492   1177.25            1656    1951     18723.14       -36.58
# Oct         2953   2625.65            3539    3357     25449.07        35.92
# Nov         3743   1448.40            1138    3717     20328.03       -20.12
# Dec         4079   3399.15            2162    1451     22795.63        12.14
#
# DataFrame after Discount:
#       Electronics   Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan         4682   900.9575            3784    3493     26224.95          NaN
# Feb         1627  1598.1700            4189    3891     23496.45       -10.40
# Mar         3068  2658.0775            1592    3290     22703.72        -3.37
# Apr         4481  2608.9475            1187    2209     22433.14        -1.19
# May         2192  3017.1600            1362    3779     22391.78        -0.18
# Jun         3578   887.2300            4325    4131     26355.03        17.70
# Jul         2801  2694.9250            2873    2817     23874.65        -9.41
# Aug         2181  3199.9525            3725    4746     29521.05        23.65
# Sep         4492  1000.6625            1656    1951     18723.14       -36.58
# Oct         2953  2231.8025            3539    3357     25449.07        35.92
# Nov         3743  1231.1400            1138    3717     20328.03       -20.12
# Dec         4079  2889.2775            2162    1451     22795.63        12.14

# %%
#Part III
import matplotlib.pyplot as plt
import seaborn as sns
#1
plt.figure(figsize=(10, 6))
for col in categories:
    plt.plot(df.index, df[col], label=col)

plt.title("Monthly Sales Trends")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.legend()
plt.grid(True)
plt.show()

#2
plt.figure(figsize=(8,6))
sns.boxplot(data=df[categories])
plt.title("Sales Distribution by Category")
plt.xlabel("Product Categories")
plt.ylabel("Sales")
plt.grid(True)
plt.show()

# %%
#Q.2
#(i)
import numpy as np

array = np.array([[1, -2, 3], [-4, 5, -6]])
absolute_values = np.abs(array)
print("\nElement-wise Absolute Values:\n", absolute_values)
#(ii)
percentile_25=np.percentile(array, 25, axis=None)
percentile_50=np.percentile(array, 50, axis=None)
percentile_75=np.percentile(array, 75, axis=None)

percentile_col=np.percentile(array, [25, 50, 75], axis=0)
percentile_row=np.percentile(array, [25, 50, 75], axis=1)

print("\nPercentiles (Flattened):", percentile_25, percentile_50, percentile_75)
print("\nPercentiles (Column-wise):\n", percentile_col)
print("\nPercentiles (Row-wise):\n", percentile_row)
#(iii)
mean_all=np.mean(array)
median_all=np.median(array)
std_all=np.std(array)

mean_col=np.mean(array, axis=0)
median_col=np.median(array, axis=0)
std_col=np.std(array, axis=0)

mean_row=np.mean(array, axis=1)
median_row=np.median(array, axis=1)
std_row=np.std(array, axis=1)

print("\nMean, Median, Std (Flattened):", mean_all, median_all, std_all)
print("\nColumn-wise:\n", mean_col, median_col, std_col)
print("\nRow-wise:\n", mean_row, median_row, std_row)
# Out:
# Element-wise Absolute Values:
#  [[1 2 3]
#  [4 5 6]]
#
# Percentiles (Flattened): -3.5 -0.5 2.5
#
# Percentiles (Column-wise):
#  [[-2.75 -0.25 -3.75]
#  [-1.5   1.5  -1.5 ]
#  [-0.25  3.25  0.75]]
#
# Percentiles (Row-wise):
#  [[-0.5 -5. ]
#  [ 1.  -4. ]
#  [ 2.   0.5]]
#
# Mean, Median, Std (Flattened): -0.5 -0.5 3.8622100754188224
#
# Column-wise:
#  [-1.5  1.5 -1.5] [-1.5  1.5 -1.5] [2.5 3.5 4.5]
#
# Row-wise:
#  [ 0.66666667 -1.66666667] [ 1. -4.] [2.05480467 4.78423336]

# %%
#Q.3
#(i)
a=np.array([-1.8,-1.6,-0.5,0.5,1.6,1.8,3.0])


floor_values=np.floor(a)
ceiling_values=np.ceil(a)
truncated_values=np.trunc(a)
rounded_values=np.round(a)

print("\nFloor Values:",floor_values)
print("Ceiling Values:",ceiling_values)
print("Truncated Values:",truncated_values)
print("Rounded Values:",rounded_values)
# Out:
# Floor Values: [-2. -2. -1.  0.  1.  1.  3.]
# Ceiling Values: [-1. -1. -0.  1.  2.  2.  3.]
# Truncated Values: [-1. -1. -0.  0.  1.  1.  3.]
# Rounded Values: [-2. -2. -0.  0.  2.  2.  3.]

# %%
#Q.4
def swap_list_elements(lst,index1,index2):
    temp=lst[index1]
    lst[index1]=lst[index2]
    lst[index2]=temp
    return lst

my_list=[2,4,6,8,10]
print("Original List:",my_list)
swapped_list=swap_list_elements(my_list,1,3)
print("Swapped List:",swapped_list)
# Out:
# Original List: [2, 4, 6, 8, 10]
# Swapped List: [2, 8, 6, 4, 10]

# %%
#Q.5
def swap(lst,i,j):
    lst[i],lst[j]=lst[j],lst[i]
    return lst

def swap2(s,elem1,elem2):
    l=list(s)
    i,j=l.index(elem1),l.index(elem2)
    return set(swap(l,i,j))

s={1,2,3,4}
print("Original Set:",s)
s=swap2(s,1,3)
print("Swapped Set:",s)
# Out:
# Original Set: {1, 2, 3, 4}
# Swapped Set: {1, 2, 3, 4}
